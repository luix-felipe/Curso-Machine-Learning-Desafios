# %% [markdown]
# ## Desafio 1 da Trilha de Visão Computacional
#
# Nesse desafio você irá implementar uma solução simples para borrar o fundo de uma imagem como uma pessoa, semelhante ao que aplicativos de vídeo chamadas fazem hoje em dia.
#
# Para isso você deverá seguir os pasos desse documento atentamente.

# %% [markdown]
# ### Instalação e Importação da Biblioteca

# %%
# !pip install opencv-python matplotlib
# Out:
# Requirement already satisfied: opencv-python in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: numpy<2.3.0,>=2 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=8 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: six>=1.5 in /home/joaoferreira/trilha_visao_computacional/.env-trilha-vc/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Ler Imagens

# %%
image_bgr = cv2.imread("desafio_1.jpeg")
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)

# %% [markdown]
# ### Transformar em Escala de Cinza

# %%
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap="gray")

# %% [markdown]
# ### Detectar as Faces
#
# Para isso iremos utilizar o `haar cascade` um método de detecção de faces clásscio. Mais detalhes sobre o `haar cascade` [aqui](https://docs.opencv.org/3.4/db/d28/tutorial_cascade_classifier.html)

# %%
detec = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
face = detec.detectMultiScale(image_gray, 1.3, 3)
copy_image_rgb = image_rgb.copy()
padding = 100
for (x, y, larg, alt) in face: #Desenhar o retângulo
    ret = cv2.rectangle(copy_image_rgb, (x, y), (x + larg, y + alt), (0, 255, 0), 3)
    y, height = max(0, y-padding), min(y+alt+padding, image_rgb.shape[0])
    x, width = max(0, x-padding), min(x+larg+padding, image_rgb.shape[1])
    face_img = image_rgb[y:height,x:width,:]
plt.imshow(copy_image_rgb)

# %%
plt.imshow(face_img)

# %% [markdown]
# ### Borrar a Imagem inteira

# %%
blured_image = cv2.GaussianBlur(image_rgb, (15,15), 20)
plt.imshow(blured_image)

# %% [markdown]
# ### Substituir Imagem Original da Face na Imagem Borrada

# %%
final_image = blured_image
final_image[y:height,x:width,:] = face_img
plt.imshow(final_image)
